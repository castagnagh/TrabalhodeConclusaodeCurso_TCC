# %%
import pandas as pd

df = pd.read_excel("Pasta1.xlsx")
df.head()
# Out:
#          DADOS_PESSOAIS: NOME DADOS_PESSOAIS: SEXO  \
# 0               Vanessa Lopes             Feminino
# 1          Jose Ariel Machado            Masculino
# 2      Jociane Bulegon Samara             Feminino
# 3  Sabrina Dalla Costa Saurim             Feminino
# 4  Patricia machado inchauspe             Feminino
#
#   DADOS_PESSOAIS: FAIXA_ETARIA DADOS_PESSOAIS: POSICAO_QUADRA  \
# 0           Entre 36 e 45 anos                        Direita
# 1           Entre 36 e 45 anos                       Esquerda
# 2           Entre 46 e 55 anos                       Esquerda
# 3           Entre 36 e 45 anos                       Esquerda
# 4           Entre 46 e 55 anos                        Direita
#
#   EXPERIENCIA: TEMPO_PADEL EXPERIENCIA: QUANTIDADE_TREINOS  \
# 0         Entre 3 e 5 anos                      Não treino
# 1         Entre 3 e 5 anos                      Não treino
# 2         Entre 3 e 5 anos                1 vez por semana
# 3               Até 2 anos                1 vez por semana
# 4          Mais de 11 anos                      Não treino
#
#   EXPERIENCIA: QUANTIDADE_JOGOS EXPERIENCIA: PARTICIPA_TORNEIOS  \
# 0            3 vezes por semana                             Sim
# 1            3 vezes por semana                             Sim
# 2              1 vez por semana                             Sim
# 3            2 vezes por semana                             Sim
# 4              1 vez por semana                             Sim
#
#   EXPERIENCIA: CATEGORIA_EM_TORNEIOS  HABILIDADE_TECNICA: SAQUE  ...  \
# 0                       4ª categoria                          3  ...
# 1                       2ª categoria                          4  ...
# 2                       4ª categoria                          3  ...
# 3                       4ª categoria                          3  ...
# 4                       4ª categoria                          4  ...
#
#               COMPOSICAO_JOGO: BANDEJA_RETOMADA_REDE  \
# 0  Minha bandeja é regular e me ajuda a manter o ...
# 1  Minha bandeja é regular e me ajuda a manter o ...
# 2  Consigo acertar a bandeja, mas com pouca profu...
# 3  Minha bandeja é regular e me ajuda a manter o ...
# 4  Minha bandeja é regular e me ajuda a manter o ...
#
#                               COMPOSICAO_JOGO: SMASH  \
# 0  Consigo acertar smashes simples, mas sem final...
# 1  Tenho boa potência e controle no smash, especi...
# 2  Consigo acertar smashes simples, mas sem final...
# 3  Consigo acertar smashes simples, mas sem final...
# 4  Tenho boa potência e controle no smash, especi...
#
#           COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_FOREHAND  \
# 0  Tenho regularidade nos golpes de fundo, com bo...
# 1  Tenho regularidade nos golpes de fundo, com bo...
# 2  Consigo manter trocas de bola, mas com pouca p...
# 3  Sou consistente e uso os golpes de fundo para ...
# 4  Tenho regularidade nos golpes de fundo, com bo...
#
#           COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_BACKHAND  \
# 0  Tenho regularidade nos golpes de fundo, com bo...
# 1  Consigo manter trocas de bola, mas com pouca p...
# 2  Consigo manter trocas de bola, mas com pouca p...
# 3  Sou consistente e uso os golpes de fundo para ...
# 4  Tenho regularidade nos golpes de fundo, com bo...
#
#                     COMPOSICAO_JOGO: DEVOLUCAO_SAQUE  \
# 0  Minhas devoluções são regulares e dificultam o...
# 1  Minhas devoluções são regulares e dificultam o...
# 2     Consigo devolver, mas sem colocação ou efeito.
# 3  Sou capaz de devolver saques com precisão e in...
# 4  Minhas devoluções são regulares e dificultam o...
#
#                 COMPOSICAO_JOGO: SAIDA_PAREDE_DEFESA  \
# 0  Sou consistente nas saídas de parede, com boa ...
# 1  Sou consistente nas saídas de parede, com boa ...
# 2  Acerto saídas simples, mas sem muita profundid...
# 3  Transformo saídas de parede em golpes estratég...
# 4  Sou consistente nas saídas de parede, com boa ...
#
#                  COMPOSICAO_JOGO:SAIDA_PAREDE_ATAQUE  \
# 0         Tento usar, mas ainda erro frequentemente.
# 1        Uso com consistência para preparar o ponto.
# 2         Tento usar, mas ainda erro frequentemente.
# 3  Sou capaz de usar essas jogadas para pressiona...
# 4             Não utilizo essas jogadas no meu jogo.
#
#                        COMPOSICAO_JOGO: MOVIMENTACAO  \
# 0  Tenho boa movimentação e me posiciono bem na m...
# 1  Tenho boa movimentação e me posiciono bem na m...
# 2  Consigo me movimentar razoavelmente, mas perco...
# 3  Tenho boa movimentação e me posiciono bem na m...
# 4  Consigo me movimentar razoavelmente, mas perco...
#
#                      COMPOSICAO_JOGO: POSICIONAMENTO  \
# 0  Trabalho bem em dupla, cobrindo a quadra de fo...
# 1  Coordeno razoavelmente, mas ainda deixo buraco...
# 2  Coordeno razoavelmente, mas ainda deixo buraco...
# 3  Trabalho bem em dupla, cobrindo a quadra de fo...
# 4  Coordeno razoavelmente, mas ainda deixo buraco...
#
#   DADOS_PESSOAIS: AUTORIZACAO
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         Sim
# 4                         Sim
#
# [5 rows x 33 columns]

# %%
#ver linhas x colunas
df.shape
# Out:
# (178, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 33 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   DADOS_PESSOAIS: NOME                        178 non-null    object
#  1   DADOS_PESSOAIS: SEXO                        178 non-null    object
#  2   DADOS_PESSOAIS: FAIXA_ETARIA                178 non-null    object
#  3   DADOS_PESSOAIS: POSICAO_QUADRA              178 non-null    object
#  4   EXPERIENCIA: TEMPO_PADEL                    178 non-null    object
#  5   EXPERIENCIA: QUANTIDADE_TREINOS             178 non-null    object
#  6   EXPERIENCIA: QUANTIDADE_JOGOS               178 non-null    object
#  7   EXPERIENCIA: PARTICIPA_TORNEIOS             178 non-null    object
#  8   EXPERIENCIA: CATEGORIA_EM_TORNEIOS          178 non-null    object
#  9   HABILIDADE_TECNICA: SAQUE                   178 non-null    int64
#  10  HABILIDADE_TECNICA: VOLEIO                  178 non-null    int64
#  11  HABILIDADE_TECNICA: SMASH                   178 non-null    int64
#  12  HABILIDADE_TECNICA: MOVIMENTACAO            178 non-null    int64
#  13  COMPOSICAO_JOGO: DEFESA_ATAQUE              178 non-null    object
#  14  COMPOSICAO_JOG0: CONTROLE_RITMO             178 non-null    object
#  15  OBJETIVO: ESTILO_DUPLAS                     178 non-null    object
#  16  OBJETIVO: FOCO                              178 non-null    object
#  17  AUTOAVALIACAO: CATEGORIA                    178 non-null    object
#  18  AUTOAVALIACAO: QUALIDADE_CATEGORIA          178 non-null    object
#  19  COMPOSICAO_JOGO: SAQUE                      178 non-null    object
#  20  COMPOSICAO_JOGO: USA_RETOQUE                178 non-null    object
#  21  COMPOSICAO_JOGO: VOLEIO_ATAQUE              178 non-null    object
#  22  COMPOSICAO_JOGO: VOLEIO_DEFESA_CONTENSAO    178 non-null    object
#  23  COMPOSICAO_JOGO: BANDEJA_RETOMADA_REDE      178 non-null    object
#  24  COMPOSICAO_JOGO: SMASH                      178 non-null    object
#  25  COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_FOREHAND  178 non-null    object
#  26  COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_BACKHAND  178 non-null    object
#  27  COMPOSICAO_JOGO: DEVOLUCAO_SAQUE            178 non-null    object
#  28  COMPOSICAO_JOGO: SAIDA_PAREDE_DEFESA        178 non-null    object
#  29  COMPOSICAO_JOGO:SAIDA_PAREDE_ATAQUE         178 non-null    object
#  30  COMPOSICAO_JOGO: MOVIMENTACAO               178 non-null    object
#  31  COMPOSICAO_JOGO: POSICIONAMENTO             178 non-null    object
#  32  DADOS_PESSOAIS: AUTORIZACAO                 115 non-null    object
# dtypes: int64(4), object(29)
# memory usage: 46.0+ KB

# %%
df.describe(include="all")
# Out:
#        DADOS_PESSOAIS: NOME DADOS_PESSOAIS: SEXO DADOS_PESSOAIS: FAIXA_ETARIA  \
# count                   178                  178                          178
# unique                  178                    2                            6
# top           Vanessa Lopes            Masculino           Entre 36 e 45 anos
# freq                      1                  118                           77
# mean                    NaN                  NaN                          NaN
# std                     NaN                  NaN                          NaN
# min                     NaN                  NaN                          NaN
# 25%                     NaN                  NaN                          NaN
# 50%                     NaN                  NaN                          NaN
# 75%                     NaN                  NaN                          NaN
# max                     NaN                  NaN                          NaN
#
#        DADOS_PESSOAIS: POSICAO_QUADRA EXPERIENCIA: TEMPO_PADEL  \
# count                             178                      178
# unique                              4                        5
# top                           Direita               Até 2 anos
# freq                               86                       70
# mean                              NaN                      NaN
# std                               NaN                      NaN
# min                               NaN                      NaN
# 25%                               NaN                      NaN
# 50%                               NaN                      NaN
# 75%                               NaN                      NaN
# max                               NaN                      NaN
#
#        EXPERIENCIA: QUANTIDADE_TREINOS EXPERIENCIA: QUANTIDADE_JOGOS  \
# count                              178                           178
# unique                               5                             4
# top                   1 vez por semana            2 vezes por semana
# freq                                85                            71
# mean                               NaN                           NaN
# std                                NaN                           NaN
# min                                NaN                           NaN
# 25%                                NaN                           NaN
# 50%                                NaN                           NaN
# 75%                                NaN                           NaN
# max                                NaN                           NaN
#
#        EXPERIENCIA: PARTICIPA_TORNEIOS EXPERIENCIA: CATEGORIA_EM_TORNEIOS  \
# count                              178                                178
# unique                               2                                  8
# top                                Sim                       4ª categoria
# freq                               166                                 53
# mean                               NaN                                NaN
# std                                NaN                                NaN
# min                                NaN                                NaN
# 25%                                NaN                                NaN
# 50%                                NaN                                NaN
# 75%                                NaN                                NaN
# max                                NaN                                NaN
#
#         HABILIDADE_TECNICA: SAQUE  ...  \
# count                  178.000000  ...
# unique                        NaN  ...
# top                           NaN  ...
# freq                          NaN  ...
# mean                     3.185393  ...
# std                      0.812619  ...
# min                      1.000000  ...
# 25%                      3.000000  ...
# 50%                      3.000000  ...
# 75%                      4.000000  ...
# max                      5.000000  ...
#
#                    COMPOSICAO_JOGO: BANDEJA_RETOMADA_REDE  \
# count                                                 178
# unique                                                  4
# top     Minha bandeja é regular e me ajuda a manter o ...
# freq                                                   86
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                    COMPOSICAO_JOGO: SMASH  \
# count                                                 178
# unique                                                  4
# top     Consigo acertar smashes simples, mas sem final...
# freq                                                   86
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_FOREHAND  \
# count                                                 178
# unique                                                  4
# top     Tenho regularidade nos golpes de fundo, com bo...
# freq                                                  100
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_BACKHAND  \
# count                                                 178
# unique                                                  4
# top     Consigo manter trocas de bola, mas com pouca p...
# freq                                                   79
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                          COMPOSICAO_JOGO: DEVOLUCAO_SAQUE  \
# count                                                 178
# unique                                                  4
# top     Minhas devoluções são regulares e dificultam o...
# freq                                                   86
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                      COMPOSICAO_JOGO: SAIDA_PAREDE_DEFESA  \
# count                                                 178
# unique                                                  4
# top     Sou consistente nas saídas de parede, com boa ...
# freq                                                   88
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                COMPOSICAO_JOGO:SAIDA_PAREDE_ATAQUE  \
# count                                          178
# unique                                           4
# top     Tento usar, mas ainda erro frequentemente.
# freq                                            96
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#                             COMPOSICAO_JOGO: MOVIMENTACAO  \
# count                                                 178
# unique                                                  4
# top     Consigo me movimentar razoavelmente, mas perco...
# freq                                                   94
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                           COMPOSICAO_JOGO: POSICIONAMENTO  \
# count                                                 178
# unique                                                  4
# top     Trabalho bem em dupla, cobrindo a quadra de fo...
# freq                                                   90
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        DADOS_PESSOAIS: AUTORIZACAO
# count                          115
# unique                           2
# top                            Sim
# freq                            93
# mean                           NaN
# std                            NaN
# min                            NaN
# 25%                            NaN
# 50%                            NaN
# 75%                            NaN
# max                            NaN
#
# [11 rows x 33 columns]

# %%
# verificar quantos valores possuem nulos
df.isnull().sum()
# Out:
# DADOS_PESSOAIS: NOME                           0
# DADOS_PESSOAIS: SEXO                           0
# DADOS_PESSOAIS: FAIXA_ETARIA                   0
# DADOS_PESSOAIS: POSICAO_QUADRA                 0
# EXPERIENCIA: TEMPO_PADEL                       0
# EXPERIENCIA: QUANTIDADE_TREINOS                0
# EXPERIENCIA: QUANTIDADE_JOGOS                  0
# EXPERIENCIA: PARTICIPA_TORNEIOS                0
# EXPERIENCIA: CATEGORIA_EM_TORNEIOS             0
# HABILIDADE_TECNICA: SAQUE                      0
# HABILIDADE_TECNICA: VOLEIO                     0
# HABILIDADE_TECNICA: SMASH                      0
# HABILIDADE_TECNICA: MOVIMENTACAO               0
# COMPOSICAO_JOGO: DEFESA_ATAQUE                 0
# COMPOSICAO_JOG0: CONTROLE_RITMO                0
# OBJETIVO: ESTILO_DUPLAS                        0
# OBJETIVO: FOCO                                 0
# AUTOAVALIACAO: CATEGORIA                       0
# AUTOAVALIACAO: QUALIDADE_CATEGORIA             0
# COMPOSICAO_JOGO: SAQUE                         0
# COMPOSICAO_JOGO: USA_RETOQUE                   0
# COMPOSICAO_JOGO: VOLEIO_ATAQUE                 0
# COMPOSICAO_JOGO: VOLEIO_DEFESA_CONTENSAO       0
# COMPOSICAO_JOGO: BANDEJA_RETOMADA_REDE         0
# COMPOSICAO_JOGO: SMASH                         0
# COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_FOREHAND     0
# COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_BACKHAND     0
# COMPOSICAO_JOGO: DEVOLUCAO_SAQUE               0
# COMPOSICAO_JOGO: SAIDA_PAREDE_DEFESA           0
# COMPOSICAO_JOGO:SAIDA_PAREDE_ATAQUE            0
# COMPOSICAO_JOGO: MOVIMENTACAO                  0
# COMPOSICAO_JOGO: POSICIONAMENTO                0
# DADOS_PESSOAIS: AUTORIZACAO                   63
# dtype: int64

# %%
# definir valor nos dados Null
# ATENÇÃO: Apenas a coluna AUTORIZACAO estava com 63 valores NaN. Setei os NaN para SIM
df = df.fillna("Sim")

# %%
#verifica se possui algum dado duplicado
df.duplicated().any()
# Out:
# np.False_

# %%
# padronizar nomes das colunas
df.columns = df.columns.str.strip().str.lower()

# selecionar apenas colunas do tipo object (texto)
texto_cols = df.select_dtypes(include='object').columns

# aplicar strip + lower apenas nas colunas de texto
df[texto_cols] = df[texto_cols].apply(lambda col: col.str.strip().str.lower())

# %%
df = df.rename(columns={
    "composicao_jogo:saida_parede_ataque": "composicao_jogo: saida_parede_ataque"
})

# %%
# verificar quantos valores possuem nulos
df.isnull().sum()
# Out:
# dados_pessoais: nome                          0
# dados_pessoais: sexo                          0
# dados_pessoais: faixa_etaria                  0
# dados_pessoais: posicao_quadra                0
# experiencia: tempo_padel                      0
# experiencia: quantidade_treinos               0
# experiencia: quantidade_jogos                 0
# experiencia: participa_torneios               0
# experiencia: categoria_em_torneios            0
# habilidade_tecnica: saque                     0
# habilidade_tecnica: voleio                    0
# habilidade_tecnica: smash                     0
# habilidade_tecnica: movimentacao              0
# composicao_jogo: defesa_ataque                0
# composicao_jog0: controle_ritmo               0
# objetivo: estilo_duplas                       0
# objetivo: foco                                0
# autoavaliacao: categoria                      0
# autoavaliacao: qualidade_categoria            0
# composicao_jogo: saque                        0
# composicao_jogo: usa_retoque                  0
# composicao_jogo: voleio_ataque                0
# composicao_jogo: voleio_defesa_contensao      0
# composicao_jogo: bandeja_retomada_rede        0
# composicao_jogo: smash                        0
# composicao_jogo: troca_bola_fundo_forehand    0
# composicao_jogo: troca_bola_fundo_backhand    0
# composicao_jogo: devolucao_saque              0
# composicao_jogo: saida_parede_defesa          0
# composicao_jogo: saida_parede_ataque          0
# composicao_jogo: movimentacao                 0
# composicao_jogo: posicionamento               0
# dados_pessoais: autorizacao                   0
# dtype: int64

# %%
for col in df.columns:
    print(f"Coluna: {col}")
    print(df[col].value_counts())
    print("-" * 40)
# Out:
# Coluna: dados_pessoais: nome
# dados_pessoais: nome
# vanessa lopes                  1
# jose ariel machado             1
# jociane bulegon samara         1
# sabrina dalla costa saurim     1
# patricia machado inchauspe     1
#                               ..
# luciano pereira                1
# letícia pires porto ribeiro    1
# fabiano cadore                 1
# rafael dessuy haag             1
# roberto maurer da silva        1
# Name: count, Length: 178, dtype: int64
# ----------------------------------------
# Coluna: dados_pessoais: sexo
# dados_pessoais: sexo
# masculino    118
# feminino      60
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: dados_pessoais: faixa_etaria
# dados_pessoais: faixa_etaria
# entre 36 e 45 anos    77
# entre 22 e 35 anos    64
# entre 46 e 55 anos    25
# entre 18 e 21 anos     6
# acima de 55 anos       5
# entre 15 e 17 anos     1
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: dados_pessoais: posicao_quadra
# dados_pessoais: posicao_quadra
# direita          86
# esquerda         67
# tanto faz        22
# não sei ainda     3
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: experiencia: tempo_padel
# experiencia: tempo_padel
# até 2 anos           70
# entre 3 e 5 anos     64
# mais de 11 anos      28
# entre 6 e 8 anos     10
# entre 9 e 11 anos     6
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: experiencia: quantidade_treinos
# experiencia: quantidade_treinos
# 1 vez por semana              85
# não treino                    83
# 2 vezes por semana             8
# mais de 3 vezes por semana     1
# 3 vezes por semana             1
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: experiencia: quantidade_jogos
# experiencia: quantidade_jogos
# 2 vezes por semana            71
# 3 vezes por semana            50
# 1 vez por semana              33
# mais de 3 vezes por semana    24
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: experiencia: participa_torneios
# experiencia: participa_torneios
# sim    166
# não     12
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: experiencia: categoria_em_torneios
# experiencia: categoria_em_torneios
# 4ª categoria    53
# 6ª categoria    28
# 3ª categoria    26
# 5ª categoria    25
# 7ª categoria    18
# iniciante       17
# 2ª categoria    10
# 1ª categoria     1
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: habilidade_tecnica: saque
# habilidade_tecnica: saque
# 3    100
# 4     47
# 2     16
# 5      8
# 1      7
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: habilidade_tecnica: voleio
# habilidade_tecnica: voleio
# 3    90
# 4    39
# 2    38
# 1     8
# 5     3
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: habilidade_tecnica: smash
# habilidade_tecnica: smash
# 3    78
# 2    54
# 4    24
# 1    16
# 5     6
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: habilidade_tecnica: movimentacao
# habilidade_tecnica: movimentacao
# 3    83
# 4    50
# 2    34
# 5     7
# 1     4
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: defesa_ataque
# composicao_jogo: defesa_ataque
# atacar           104
# defender          62
# ainda não sei     12
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jog0: controle_ritmo
# composicao_jog0: controle_ritmo
# sim                  97
# não                  46
# não sei responder    35
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: objetivo: estilo_duplas
# objetivo: estilo_duplas
# fixas        92
# rotativas    66
# não sei      20
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: objetivo: foco
# objetivo: foco
# melhorar como jogador                                            109
# competir                                                          33
# socializar                                                        23
# não sei                                                            2
# praticar uma atividade fisica e socializar                         1
# as três alternativas                                               1
# um pouco de todos                                                  1
# todos as opcoes acima                                              1
# melhorar na parte técnica, avançado em categoria e competição      1
# todos                                                              1
# todas as alternativas                                              1
# melhorar como jogador e socializar                                 1
# as três primeiras opções em conjunto                               1
# socializar, fazer atividade fisica e melhorar como jogador         1
# todas alternativas                                                 1
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: autoavaliacao: categoria
# autoavaliacao: categoria
# 4ª categoria    49
# 5ª categoria    32
# 6ª categoria    31
# 3ª categoria    29
# 7ª categoria    16
# 2ª categoria    10
# iniciante       10
# 1ª categoria     1
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: autoavaliacao: qualidade_categoria
# autoavaliacao: qualidade_categoria
# médio      104
# forte       48
# fraco       25
# não sei      1
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: saque
# composicao_jogo: saque
# meu saque é consistente, consigo variar entre potência e colocação.              98
# consigo acertar o saque com regularidade, mas sem muito controle ou potência.    48
# consigo sacar estrategicamente, pressionando o adversário.                       30
# raramente consigo acertar o saque em áreas estratégicas.                          2
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: usa_retoque
# composicao_jogo: usa_retoque
# sim, mas com dificuldade em manter a qualidade.                        83
# sim, e geralmente consigo preparar o ponto com ele.                    72
# sim, e uso o retoque como parte fundamental da construção do ponto.    12
# não.                                                                   11
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: voleio_ataque
# composicao_jogo: voleio_ataque
# acerto voleios simples, mas tenho dificuldade em pressionar o adversário.    91
# consigo executar voleios sólidos com boa colocação.                          76
# muitas vezes eu erro a direção ou intensidade.                                7
# meus voleios são consistentes e coloco pressão no adversário.                 4
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: voleio_defesa_contensao
# composicao_jogo: voleio_defesa_contensao
# acerto voleios defensivos básicos, mas com pouca profundidade ou controle.    87
# tenho boa técnica para defender voleios e manter a bola em jogo.              74
# tenho dificuldade em devolver bolas rápidas ou com efeito.                    14
# sou capaz de transformar a defesa em ataque nos voleios.                       3
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: bandeja_retomada_rede
# composicao_jogo: bandeja_retomada_rede
# minha bandeja é regular e me ajuda a manter o ponto.               86
# consigo acertar a bandeja, mas com pouca profundidade.             52
# tenho dificuldade em executar a bandeja com controle.              22
# uso a bandeja para controlar o ponto e pressionar o adversário.    18
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: smash
# composicao_jogo: smash
# consigo acertar smashes simples, mas sem finalizações efetivas.                 86
# tenho boa potência e controle no smash, especialmente para finalizar pontos.    56
# dificuldade em acertar o smash com potência e controle.                         26
# meu smash é consistente e me permite definir pontos regularmente.               10
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: troca_bola_fundo_forehand
# composicao_jogo: troca_bola_fundo_forehand
# tenho regularidade nos golpes de fundo, com boa direção e profundidade.          100
# consigo manter trocas de bola, mas com pouca precisão.                            63
# sou consistente e uso os golpes de fundo para construir jogadas estratégicas.     12
# erro frequentemente ou tenho dificuldade em acertar profundidade.                  3
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: troca_bola_fundo_backhand
# composicao_jogo: troca_bola_fundo_backhand
# consigo manter trocas de bola, mas com pouca precisão.                           79
# tenho regularidade nos golpes de fundo, com boa direção e profundidade.          78
# sou consistente e uso os golpes de fundo para construir jogadas estratégicas.    15
# erro frequentemente ou tenho dificuldade em acertar profundidade.                 6
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: devolucao_saque
# composicao_jogo: devolucao_saque
# minhas devoluções são regulares e dificultam o próximo golpe do adversário.    86
# consigo devolver, mas sem colocação ou efeito.                                 81
# sou capaz de devolver saques com precisão e iniciar o ponto em vantagem.        7
# tenho dificuldade em devolver saques com controle.                              4
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: saida_parede_defesa
# composicao_jogo: saida_parede_defesa
# sou consistente nas saídas de parede, com boa direção.             88
# acerto saídas simples, mas sem muita profundidade.                 69
# transformo saídas de parede em golpes estratégicos para atacar.    14
# tenho dificuldade em realizar a saída de parede com controle.       7
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: saida_parede_ataque
# composicao_jogo: saida_parede_ataque
# tento usar, mas ainda erro frequentemente.                             96
# uso com consistência para preparar o ponto.                            51
# sou capaz de usar essas jogadas para pressionar e finalizar pontos.    24
# não utilizo essas jogadas no meu jogo.                                  7
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: movimentacao
# composicao_jogo: movimentacao
# consigo me movimentar razoavelmente, mas perco algumas bolas.        94
# tenho boa movimentação e me posiciono bem na maioria das jogadas.    70
# tenho excelente movimentação e antecipo jogadas do adversário.        7
# tenho dificuldade em me posicionar corretamente.                      7
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: composicao_jogo: posicionamento
# composicao_jogo: posicionamento
# trabalho bem em dupla, cobrindo a quadra de forma eficiente.                90
# coordeno razoavelmente, mas ainda deixo buracos na defesa.                  76
# tenho excelente entrosamento e crio jogadas estratégicas com o parceiro.    10
# tenho dificuldade em coordenar movimentos com o parceiro.                    2
# Name: count, dtype: int64
# ----------------------------------------
# Coluna: dados_pessoais: autorizacao
# dados_pessoais: autorizacao
# sim    156
# não     22
# Name: count, dtype: int64
# ----------------------------------------

# %%
# verificando os valores unicos por coluna (importante para fazer o mapeamento)
for col in df.columns:
    print(col, df[col].unique())
# Out:
# dados_pessoais: nome ['vanessa lopes' 'jose ariel machado' 'jociane bulegon samara'
#  'sabrina dalla costa saurim' 'patricia machado inchauspe'
#  'lorenzo iop laporta' 'carlos eduardo reverbel de souza' 'pedro alves'
#  'carolina vieira' 'ricardo giuliani martini' 'andré morgental weber'
#  'lorenzo sartori rizzatti' 'ykaraíma moraes da costa caetano'
#  'marcos hahn' 'andré pivetta' 'manoel caetano dorneles nogueira'
#  'caroline martins machado' 'igor cantarelli' 'ricardo ferreira schroder'
#  'gustavo boschin' 'thalles de almeida' 'gleiane ruviaro'
#  'marcus vinícius real perini' 'juliana de almeida surdo'
#  'carlos augusto de moura alves' 'felipe de andrades knackfuss'
#  'juliana corrêa soares' 'jonatan saraiva de abreu' 'lucas felipe zucatto'
#  'mario couto' 'diogo vieira de mello' 'paulo lima' 'eggres'
#  'juliana vargas' 'tatiane de oliveira pinto' 'gabriel biasuz trevisan'
#  'gabriela curto saldanha' 'jamille farias hoffmann' 'guido ruviâro'
#  'ronier pauletto gutierrez' 'igor rocha monteiro'
#  'giordana fonseca osmari' 'maria altermann' 'daliana oliveira'
#  'matheus gindri' 'évelin santos vaz' 'darciane iop da silva righi'
#  'fernanda rossatto lameira' 'júlia almeida sturmer' 'fernanda barbisan'
#  'géssica sório' 'bruno de oliveira pires' 'maria luiza reverbel de souza'
#  'alessandro porto' 'eglon moreira de lima jr' 'marco souza'
#  'ana laura inchauspe pires' 'cris raquel machado alves' 'francielly fan'
#  'luiz eduardo wagner' 'bruna dos santos' 'daniel montardo'
#  'carlos norberto' 'carolina pelzer sussenbach' 'alexandre zamberlan'
#  'bruno gomes dias' 'dilcir antônio cortina' 'lilian'
#  'lorenzo de reuter sperandio' 'andre mallmann' 'gabriel bertolin'
#  'tatiana fernandes pereira' 'daniel meirelles'
#  'humberto da fontoura mota' 'rodolfo borgmann' 'luiza vieira machado'
#  'jonas alexis skupien' 'juliano soares da silva' 'pablo do amaral alonço'
#  'augusto sichinel de freitas' 'nargia perla vasconcelos'
#  'maria ines gadret' 'janaina massirer' 'maicon augusto felix melo'
#  'felipe' 'carla niciele minussi lamberty' 'clarissa retamoso'
#  'ricardo goulart greco' 'gelmari mello de mellp' 'thiago waechter'
#  'ana paula dal maso' 'aquiles dal forno' 'gabriel marques'
#  'fernando salles' 'zoio' 'leandro brutti' 'jullan ruviaro' 'renan mellor'
#  'vinicius borba paz leão' 'ederson josé reis' 'eduardo botega'
#  'bruno cardoso' 'juliana rossato' 'daniel saurin' 'joão gracioli'
#  'lucas barros de souza' 'raquel bassan' 'nicolas tarragô just'
#  'thiago piovezan' 'matheus muniz welter' 'juliana simão pereira'
#  'diana carla zanovello' 'otavio augusto docki gomes' 'felipe lins alves'
#  'samir frazzon samara' 'vinicius de david' 'nathalia avila'
#  'romulo soares castagnino' 'douglas marques bilha' 'alessandro rocha'
#  'fabíola oliveira' 'lorenzo colvero sarzi sartori'
#  'amanda de moraes brasil' 'isadora seixas' 'mateus beck rutzig'
#  'natalia de oliveira lopes' 'cassiano rech' 'ruy sales' 'raul sales'
#  'vicente piccinini' 'carolina gressler barbosa' 'amanda tomazi'
#  'carlos wilson radtke tavares' 'jamile bulegon samara'
#  'tiago ruthschilling' 'joice patrícia naidon' 'lucas eich lima'
#  'thiago ferreira machado' 'arthur castiel' 'guideverson'
#  'daniela dalla lana' 'fabricio mozzaquatro de freitas'
#  'luis fernando barros de mello' 'cláudia coelho teixeira beck'
#  'gustavo veloso soares' 'ana paula fonseca de barros'
#  'ricardo frohlich da silva' 'rodrigo bernardi' 'marina lopes machado'
#  'carlan vargas lima' 'guilherme vargas pereira' 'paulo andre dutra'
#  'deivison morim pasa' 'rodrigo aita' 'elenton anversa finger'
#  'luiz fernando crispan' 'vagner neuhaus' 'guilherme nonnemacher'
#  'roberto christ' 'guilherme martins ruviaro' 'rodrigo brunhauser karsten'
#  'carlos hugo del priore winckler neto' 'cristian martins da silva'
#  'giuliano laporta' 'filipe mello pasetto' 'enrico iraja' 'fábio lemos'
#  'juliano dellazzana' 'luiza adaime' 'amanda hoffmann rossi'
#  'eduarda soares schmidt' 'natalia kist' 'marcos minuzzi'
#  'luciano pereira' 'letícia pires porto ribeiro' 'fabiano cadore'
#  'rafael dessuy haag' 'roberto maurer da silva']
# dados_pessoais: sexo ['feminino' 'masculino']
# dados_pessoais: faixa_etaria ['entre 36 e 45 anos' 'entre 46 e 55 anos' 'entre 22 e 35 anos'
#  'acima de 55 anos' 'entre 18 e 21 anos' 'entre 15 e 17 anos']
# dados_pessoais: posicao_quadra ['direita' 'esquerda' 'tanto faz' 'não sei ainda']
# experiencia: tempo_padel ['entre 3 e 5 anos' 'até 2 anos' 'mais de 11 anos' 'entre 6 e 8 anos'
#  'entre 9 e 11 anos']
# experiencia: quantidade_treinos ['não treino' '1 vez por semana' '2 vezes por semana'
#  'mais de 3 vezes por semana' '3 vezes por semana']
# experiencia: quantidade_jogos ['3 vezes por semana' '1 vez por semana' '2 vezes por semana'
#  'mais de 3 vezes por semana']
# experiencia: participa_torneios ['sim' 'não']
# experiencia: categoria_em_torneios ['4ª categoria' '2ª categoria' '6ª categoria' '3ª categoria'
#  '5ª categoria' 'iniciante' '7ª categoria' '1ª categoria']
# habilidade_tecnica: saque [3 4 2 5 1]
# habilidade_tecnica: voleio [4 3 2 1 5]
# habilidade_tecnica: smash [3 2 4 5 1]
# habilidade_tecnica: movimentacao [4 3 2 5 1]
# composicao_jogo: defesa_ataque ['defender' 'atacar' 'ainda não sei']
# composicao_jog0: controle_ritmo ['sim' 'não sei responder' 'não']
# objetivo: estilo_duplas ['rotativas' 'fixas' 'não sei']
# objetivo: foco ['melhorar como jogador' 'praticar uma atividade fisica e socializar'
#  'socializar' 'competir' 'um pouco de todos' 'as três alternativas'
#  'todos as opcoes acima'
#  'melhorar na parte técnica, avançado em categoria e competição'
#  'todas as alternativas' 'todos' 'melhorar como jogador e socializar'
#  'as três primeiras opções em conjunto'
#  'socializar, fazer atividade fisica e melhorar como jogador' 'não sei'
#  'todas alternativas']
# autoavaliacao: categoria ['4ª categoria' '2ª categoria' '6ª categoria' '3ª categoria'
#  '5ª categoria' 'iniciante' '7ª categoria' '1ª categoria']
# autoavaliacao: qualidade_categoria ['médio' 'fraco' 'forte' 'não sei']
# composicao_jogo: saque ['meu saque é consistente, consigo variar entre potência e colocação.'
#  'consigo acertar o saque com regularidade, mas sem muito controle ou potência.'
#  'consigo sacar estrategicamente, pressionando o adversário.'
#  'raramente consigo acertar o saque em áreas estratégicas.']
# composicao_jogo: usa_retoque ['sim, mas com dificuldade em manter a qualidade.'
#  'sim, e geralmente consigo preparar o ponto com ele.'
#  'sim, e uso o retoque como parte fundamental da construção do ponto.'
#  'não.']
# composicao_jogo: voleio_ataque ['acerto voleios simples, mas tenho dificuldade em pressionar o adversário.'
#  'consigo executar voleios sólidos com boa colocação.'
#  'muitas vezes eu erro a direção ou intensidade.'
#  'meus voleios são consistentes e coloco pressão no adversário.']
# composicao_jogo: voleio_defesa_contensao ['tenho boa técnica para defender voleios e manter a bola em jogo.'
#  'acerto voleios defensivos básicos, mas com pouca profundidade ou controle.'
#  'tenho dificuldade em devolver bolas rápidas ou com efeito.'
#  'sou capaz de transformar a defesa em ataque nos voleios.']
# composicao_jogo: bandeja_retomada_rede ['minha bandeja é regular e me ajuda a manter o ponto.'
#  'consigo acertar a bandeja, mas com pouca profundidade.'
#  'uso a bandeja para controlar o ponto e pressionar o adversário.'
#  'tenho dificuldade em executar a bandeja com controle.']
# composicao_jogo: smash ['consigo acertar smashes simples, mas sem finalizações efetivas.'
#  'tenho boa potência e controle no smash, especialmente para finalizar pontos.'
#  'meu smash é consistente e me permite definir pontos regularmente.'
#  'dificuldade em acertar o smash com potência e controle.']
# composicao_jogo: troca_bola_fundo_forehand ['tenho regularidade nos golpes de fundo, com boa direção e profundidade.'
#  'consigo manter trocas de bola, mas com pouca precisão.'
#  'sou consistente e uso os golpes de fundo para construir jogadas estratégicas.'
#  'erro frequentemente ou tenho dificuldade em acertar profundidade.']
# composicao_jogo: troca_bola_fundo_backhand ['tenho regularidade nos golpes de fundo, com boa direção e profundidade.'
#  'consigo manter trocas de bola, mas com pouca precisão.'
#  'sou consistente e uso os golpes de fundo para construir jogadas estratégicas.'
#  'erro frequentemente ou tenho dificuldade em acertar profundidade.']
# composicao_jogo: devolucao_saque ['minhas devoluções são regulares e dificultam o próximo golpe do adversário.'
#  'consigo devolver, mas sem colocação ou efeito.'
#  'sou capaz de devolver saques com precisão e iniciar o ponto em vantagem.'
#  'tenho dificuldade em devolver saques com controle.']
# composicao_jogo: saida_parede_defesa ['sou consistente nas saídas de parede, com boa direção.'
#  'acerto saídas simples, mas sem muita profundidade.'
#  'transformo saídas de parede em golpes estratégicos para atacar.'
#  'tenho dificuldade em realizar a saída de parede com controle.']
# composicao_jogo: saida_parede_ataque ['tento usar, mas ainda erro frequentemente.'
#  'uso com consistência para preparar o ponto.'
#  'sou capaz de usar essas jogadas para pressionar e finalizar pontos.'
#  'não utilizo essas jogadas no meu jogo.']
# composicao_jogo: movimentacao ['tenho boa movimentação e me posiciono bem na maioria das jogadas.'
#  'consigo me movimentar razoavelmente, mas perco algumas bolas.'
#  'tenho excelente movimentação e antecipo jogadas do adversário.'
#  'tenho dificuldade em me posicionar corretamente.']
# composicao_jogo: posicionamento ['trabalho bem em dupla, cobrindo a quadra de forma eficiente.'
#  'coordeno razoavelmente, mas ainda deixo buracos na defesa.'
#  'tenho excelente entrosamento e crio jogadas estratégicas com o parceiro.'
#  'tenho dificuldade em coordenar movimentos com o parceiro.']
# dados_pessoais: autorizacao ['sim' 'não']

# %%
# fazendo o dicionário/mapeamento das colunas que possuem textos
# ordem de natural de 1 = fraco até 5 = forte
# Colunas de habilidade técnica

# COMPOSICAO_JOGO: SAQUE
mapa_saque = {
    "raramente consigo acertar o saque em áreas estratégicas.": 1,
    "consigo acertar o saque com regularidade, mas sem muito controle ou potência.": 2,
    "meu saque é consistente, consigo variar entre potência e colocação.": 3,
    "consigo sacar estrategicamente, pressionando o adversário.": 4
}

# COMPOSICAO_JOGO: USA_RETOQUE
mapa_retoque = {
    "não.": 1,
    "sim, mas com dificuldade em manter a qualidade.": 2,
    "sim, e geralmente consigo preparar o ponto com ele.": 3,
    "sim, e uso o retoque como parte fundamental da construção do ponto.": 4
}

# COMPOSICAO_JOGO: VOLEIO_ATAQUE
mapa_voleio_ataque = {
    "acerto voleios simples, mas tenho dificuldade em pressionar o adversário.": 1,
    "consigo executar voleios sólidos com boa colocação.": 2,
    "muitas vezes eu erro a direção ou intensidade.": 3,
    "meus voleios são consistentes e coloco pressão no adversário.": 4
}

# COMPOSICAO_JOGO: VOLEIO_DEFESA_CONTENSAO
mapa_voleio_defesa = {
    "tenho dificuldade em devolver bolas rápidas ou com efeito.": 1,
    "acerto voleios defensivos básicos, mas com pouca profundidade ou controle.": 2,
    "tenho boa técnica para defender voleios e manter a bola em jogo.": 3,
    "sou capaz de transformar a defesa em ataque nos voleios.": 4
}

# COMPOSICAO_JOGO: BANDEJA_RETOMADA_REDE
mapa_bandeja = {
    "tenho dificuldade em executar a bandeja com controle.": 1,
    "consigo acertar a bandeja, mas com pouca profundidade.": 2,
    "minha bandeja é regular e me ajuda a manter o ponto.": 3,
    "uso a bandeja para controlar o ponto e pressionar o adversário.": 4
}

# COMPOSICAO_JOGO: SMASH
mapa_smash = {
    "dificuldade em acertar o smash com potência e controle.": 1,
    "consigo acertar smashes simples, mas sem finalizações efetivas.": 2,
    "tenho boa potência e controle no smash, especialmente para finalizar pontos.": 3,
    "meu smash é consistente e me permite definir pontos regularmente.": 4
}

# COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_FOREHAND
mapa_forehand = {
    "erro frequentemente ou tenho dificuldade em acertar profundidade.": 1,
    "consigo manter trocas de bola, mas com pouca precisão.": 2,
    "tenho regularidade nos golpes de fundo, com boa direção e profundidade.": 3,
    "sou consistente e uso os golpes de fundo para construir jogadas estratégicas.": 4
}

# COMPOSICAO_JOGO: TROCA_BOLA_FUNDO_BACKHAND (mesmo padrão do forehand)
mapa_backhand = mapa_forehand

# COMPOSICAO_JOGO: DEVOLUCAO_SAQUE
mapa_devolucao = {
    "tenho dificuldade em devolver saques com controle.": 1,
    "consigo devolver, mas sem colocação ou efeito.": 2,
    "minhas devoluções são regulares e dificultam o próximo golpe do adversário.": 3,
    "sou capaz de devolver saques com precisão e iniciar o ponto em vantagem.": 4
}

# COMPOSICAO_JOGO: SAIDA_PAREDE_DEFESA
mapa_saida_defesa = {
    "tenho dificuldade em realizar a saída de parede com controle.": 1,
    "acerto saídas simples, mas sem muita profundidade.": 2,
    "sou consistente nas saídas de parede, com boa direção.": 3,
    "transformo saídas de parede em golpes estratégicos para atacar.": 4
}

# COMPOSICAO_JOGO: SAIDA_PAREDE_ATAQUE
mapa_saida_ataque = {
    "não utilizo essas jogadas no meu jogo.": 1,
    "tento usar, mas ainda erro frequentemente.": 2,
    "uso com consistência para preparar o ponto.": 3,
    "sou capaz de usar essas jogadas para pressionar e finalizar pontos.": 4
}

# COMPOSICAO_JOGO: MOVIMENTACAO
mapa_movimentacao = {
    "tenho dificuldade em me posicionar corretamente.": 1,
    "consigo me movimentar razoavelmente, mas perco algumas bolas.": 2,
    "tenho boa movimentação e me posiciono bem na maioria das jogadas.": 3,
    "tenho excelente movimentação e antecipo jogadas do adversário.": 4
}

# COMPOSICAO_JOGO: POSICIONAMENTO
mapa_posicionamento = {
    "tenho dificuldade em coordenar movimentos com o parceiro.": 1,
    "coordeno razoavelmente, mas ainda deixo buracos na defesa.": 2,
    "trabalho bem em dupla, cobrindo a quadra de forma eficiente.": 3,
    "tenho excelente entrosamento e crio jogadas estratégicas com o parceiro.": 4
}

# %%
# colunas ordinais simples, não importa a escala
# FAIXA_ETARIA
mapa_faixa = {
    "entre 15 e 17 anos": 1,
    "entre 18 e 21 anos": 2,
    "entre 22 e 35 anos": 3,
    "entre 36 e 45 anos": 4,
    "entre 46 e 55 anos": 5,
    "acima de 55 anos": 6
}

# TEMPO_PADEL
mapa_tempo = {
    "até 2 anos": 1,
    "entre 3 e 5 anos": 2,
    "entre 6 e 8 anos": 3,
    "entre 9 e 11 anos": 4,
    "mais de 11 anos": 5
}

# QUANTIDADE_TREINOS
mapa_treinos = {
    "não treino": 0,
    "1 vez por semana": 1,
    "2 vezes por semana": 2,
    "3 vezes por semana": 3,
    "mais de 3 vezes por semana": 4
}

# QUANTIDADE_JOGOS
mapa_jogos = mapa_treinos  # mesma lógica

# CATEGORIA_EM_TORNEIOS e AUTOAVALIACAO: CATEGORIA
mapa_categoria = {
    "iniciante": 1,
    "7ª categoria": 2,
    "6ª categoria": 3,
    "5ª categoria": 4,
    "4ª categoria": 5,
    "3ª categoria": 6,
    "2ª categoria": 7,
    "1ª categoria": 8
}

# QUALIDADE_CATEGORIA
mapa_qualidade = {
    "fraco": 1,
    "médio": 2,
    "forte": 3,
    "não sei": 0
}

# POSIÇÃO NA QUADRA
mapa_posicao_quadra = {
    "direita": 1,
    "esquerda": 2,
    "tanto faz": 3,
    "não sei ainda": 4
}

# DEFESA/ATAQUE NO JOGO
mapa_defesa_ataque = {
    "atacar": 1,
    "defender": 2,
    "ainda não sei": 3
}

# CONTROLE DE RITMO
mapa_controle_ritmo = {
    "sim": 1,
    "não": 2,
    "não sei responder": 3
}

# ESTILO DE DUPLAS
mapa_estilo_duplas = {
    "fixas": 1,
    "rotativas": 2,
    "não sei": 3
}

# FOCO / OBJETIVO
mapa_objetivo_foco = {
    "melhorar como jogador": 1,
    "praticar uma atividade fisica e socializar": 2,
    "socializar": 3,
    "competir": 4,
    "um pouco de todos": 5,
    "as três alternativas": 6,
    "todas alternativas": 7,
    "todos as opcoes acima": 8,
    "melhorar na parte técnica, avançado em categoria e competição": 9,
    "melhorar como jogador e socializar": 10,
    "as três primeiras opções em conjunto": 11,
    "socializar, fazer atividade fisica e melhorar como jogador": 12,
    "não sei": 13
}

# %%
# atribuindo os mapas a cada coluna
df["composicao_jogo: saque"] = df["composicao_jogo: saque"].map(mapa_saque)
df["composicao_jogo: usa_retoque"] = df["composicao_jogo: usa_retoque"].map(mapa_retoque)
df["composicao_jogo: voleio_ataque"] = df["composicao_jogo: voleio_ataque"].map(mapa_voleio_ataque)
df["composicao_jogo: voleio_defesa_contensao"] = df["composicao_jogo: voleio_defesa_contensao"].map(mapa_voleio_defesa)
df["composicao_jogo: bandeja_retomada_rede"] = df["composicao_jogo: bandeja_retomada_rede"].map(mapa_bandeja)
df["composicao_jogo: smash"] = df["composicao_jogo: smash"].map(mapa_smash)
df["composicao_jogo: troca_bola_fundo_forehand"] = df["composicao_jogo: troca_bola_fundo_forehand"].map(mapa_forehand)
df["composicao_jogo: troca_bola_fundo_backhand"] = df["composicao_jogo: troca_bola_fundo_backhand"].map(mapa_backhand)
df["composicao_jogo: devolucao_saque"] = df["composicao_jogo: devolucao_saque"].map(mapa_devolucao)  # invertido
df["composicao_jogo: saida_parede_defesa"] = df["composicao_jogo: saida_parede_defesa"].map(mapa_saida_defesa)  # espaço depois dos dois pontos
df["composicao_jogo: saida_parede_ataque"] = df["composicao_jogo: saida_parede_ataque"].map(mapa_saida_ataque)
df["composicao_jogo: movimentacao"] = df["composicao_jogo: movimentacao"].map(mapa_movimentacao)
df["composicao_jogo: posicionamento"] = df["composicao_jogo: posicionamento"].map(mapa_posicionamento)
df["dados_pessoais: faixa_etaria"] = df["dados_pessoais: faixa_etaria"].map(mapa_faixa)
df["experiencia: tempo_padel"] = df["experiencia: tempo_padel"].map(mapa_tempo)
df["experiencia: quantidade_treinos"] = df["experiencia: quantidade_treinos"].map(mapa_treinos)
df["autoavaliacao: categoria"] = df["autoavaliacao: categoria"].map(mapa_categoria)
df["autoavaliacao: qualidade_categoria"] = df["autoavaliacao: qualidade_categoria"].map(mapa_qualidade)
df["experiencia: quantidade_jogos"] = df["experiencia: quantidade_jogos"].map(mapa_jogos)
df["experiencia: categoria_em_torneios"] = df["experiencia: categoria_em_torneios"].map(mapa_categoria)
df['dados_pessoais: posicao_quadra'] = df['dados_pessoais: posicao_quadra'].map(mapa_posicao_quadra)
df['composicao_jogo: defesa_ataque'] = df['composicao_jogo: defesa_ataque'].map(mapa_defesa_ataque)
df['composicao_jog0: controle_ritmo'] = df['composicao_jog0: controle_ritmo'].map(mapa_controle_ritmo)
df['objetivo: estilo_duplas'] = df['objetivo: estilo_duplas'].map(mapa_estilo_duplas)
df['objetivo: foco'] = df['objetivo: foco'].map(mapa_objetivo_foco)

# %%
df['dados_pessoais: sexo'] = df['dados_pessoais: sexo'].map({'feminino': 0, 'masculino': 1})
df['experiencia: participa_torneios'] = df['experiencia: participa_torneios'].map({'não': 0, 'sim': 1})
df['dados_pessoais: autorizacao'] = df['dados_pessoais: autorizacao'].map({'não': 0, 'sim': 1})

# %%
print(df.columns)
# Out:
# Index(['dados_pessoais: nome', 'dados_pessoais: sexo',
#        'dados_pessoais: faixa_etaria', 'dados_pessoais: posicao_quadra',
#        'experiencia: tempo_padel', 'experiencia: quantidade_treinos',
#        'experiencia: quantidade_jogos', 'experiencia: participa_torneios',
#        'experiencia: categoria_em_torneios', 'habilidade_tecnica: saque',
#        'habilidade_tecnica: voleio', 'habilidade_tecnica: smash',
#        'habilidade_tecnica: movimentacao', 'composicao_jogo: defesa_ataque',
#        'composicao_jog0: controle_ritmo', 'objetivo: estilo_duplas',
#        'objetivo: foco', 'autoavaliacao: categoria',
#        'autoavaliacao: qualidade_categoria', 'composicao_jogo: saque',
#        'composicao_jogo: usa_retoque', 'composicao_jogo: voleio_ataque',
#        'composicao_jogo: voleio_defesa_contensao',
#        'composicao_jogo: bandeja_retomada_rede', 'composicao_jogo: smash',
#        'composicao_jogo: troca_bola_fundo_forehand',
#        'composicao_jogo: troca_bola_fundo_backhand',
#        'composicao_jogo: devolucao_saque',
#        'composicao_jogo: saida_parede_defesa',
#        'composicao_jogo: saida_parede_ataque', 'composicao_jogo: movimentacao',
#        'composicao_jogo: posicionamento', 'dados_pessoais: autorizacao'],
#       dtype='object')

# %%
# Ver quantos valores faltantes por coluna
print(df.isna().sum())
# Out:
# dados_pessoais: nome                          0
# dados_pessoais: sexo                          0
# dados_pessoais: faixa_etaria                  0
# dados_pessoais: posicao_quadra                0
# experiencia: tempo_padel                      0
# experiencia: quantidade_treinos               0
# experiencia: quantidade_jogos                 0
# experiencia: participa_torneios               0
# experiencia: categoria_em_torneios            0
# habilidade_tecnica: saque                     0
# habilidade_tecnica: voleio                    0
# habilidade_tecnica: smash                     0
# habilidade_tecnica: movimentacao              0
# composicao_jogo: defesa_ataque                0
# composicao_jog0: controle_ritmo               0
# objetivo: estilo_duplas                       0
# objetivo: foco                                2
# autoavaliacao: categoria                      0
# autoavaliacao: qualidade_categoria            0
# composicao_jogo: saque                        0
# composicao_jogo: usa_retoque                  0
# composicao_jogo: voleio_ataque                0
# composicao_jogo: voleio_defesa_contensao      0
# composicao_jogo: bandeja_retomada_rede        0
# composicao_jogo: smash                        0
# composicao_jogo: troca_bola_fundo_forehand    0
# composicao_jogo: troca_bola_fundo_backhand    0
# composicao_jogo: devolucao_saque              0
# composicao_jogo: saida_parede_defesa          0
# composicao_jogo: saida_parede_ataque          0
# composicao_jogo: movimentacao                 0
# composicao_jogo: posicionamento               0
# dados_pessoais: autorizacao                   0
# dtype: int64

# %%
# Mostrar todas as colunas, mas apenas as primeiras 5 linhas
pd.set_option('display.max_columns', None)

# Exibe apenas as 5 primeiras linhas, mas todas as colunas
df.head()
# Out:
#          dados_pessoais: nome  dados_pessoais: sexo  \
# 0               vanessa lopes                     0
# 1          jose ariel machado                     1
# 2      jociane bulegon samara                     0
# 3  sabrina dalla costa saurim                     0
# 4  patricia machado inchauspe                     0
#
#    dados_pessoais: faixa_etaria  dados_pessoais: posicao_quadra  \
# 0                             4                               1
# 1                             4                               2
# 2                             5                               2
# 3                             4                               2
# 4                             5                               1
#
#    experiencia: tempo_padel  experiencia: quantidade_treinos  \
# 0                         2                                0
# 1                         2                                0
# 2                         2                                1
# 3                         1                                1
# 4                         5                                0
#
#    experiencia: quantidade_jogos  experiencia: participa_torneios  \
# 0                              3                                1
# 1                              3                                1
# 2                              1                                1
# 3                              2                                1
# 4                              1                                1
#
#    experiencia: categoria_em_torneios  habilidade_tecnica: saque  \
# 0                                   5                          3
# 1                                   7                          4
# 2                                   5                          3
# 3                                   5                          3
# 4                                   5                          4
#
#    habilidade_tecnica: voleio  habilidade_tecnica: smash  \
# 0                           4                          3
# 1                           4                          3
# 2                           3                          2
# 3                           3                          3
# 4                           3                          3
#
#    habilidade_tecnica: movimentacao  composicao_jogo: defesa_ataque  \
# 0                                 4                               2
# 1                                 3                               1
# 2                                 3                               1
# 3                                 3                               1
# 4                                 4                               1
#
#    composicao_jog0: controle_ritmo  objetivo: estilo_duplas  objetivo: foco  \
# 0                                1                        2             1.0
# 1                                1                        2             2.0
# 2                                3                        2             1.0
# 3                                1                        2             3.0
# 4                                1                        1             3.0
#
#    autoavaliacao: categoria  autoavaliacao: qualidade_categoria  \
# 0                         5                                   2
# 1                         7                                   2
# 2                         5                                   2
# 3                         5                                   1
# 4                         5                                   2
#
#    composicao_jogo: saque  composicao_jogo: usa_retoque  \
# 0                       3                             2
# 1                       3                             3
# 2                       2                             2
# 3                       2                             4
# 4                       4                             2
#
#    composicao_jogo: voleio_ataque  composicao_jogo: voleio_defesa_contensao  \
# 0                               1                                         3
# 1                               2                                         3
# 2                               2                                         2
# 3                               1                                         2
# 4                               1                                         3
#
#    composicao_jogo: bandeja_retomada_rede  composicao_jogo: smash  \
# 0                                       3                       2
# 1                                       3                       3
# 2                                       2                       2
# 3                                       3                       2
# 4                                       3                       3
#
#    composicao_jogo: troca_bola_fundo_forehand  \
# 0                                           3
# 1                                           3
# 2                                           2
# 3                                           4
# 4                                           3
#
#    composicao_jogo: troca_bola_fundo_backhand  \
# 0                                           3
# 1                                           2
# 2                                           2
# 3                                           4
# 4                                           3
#
#    composicao_jogo: devolucao_saque  composicao_jogo: saida_parede_defesa  \
# 0                                 3                                     3
# 1                                 3                                     3
# 2                                 2                                     2
# 3                                 4                                     4
# 4                                 3                                     3
#
#    composicao_jogo: saida_parede_ataque  composicao_jogo: movimentacao  \
# 0                                     2                              3
# 1                                     3                              3
# 2                                     2                              2
# 3                                     4                              3
# 4                                     1                              2
#
#    composicao_jogo: posicionamento  dados_pessoais: autorizacao
# 0                                3                            1
# 1                                2                            1
# 2                                2                            1
# 3                                3                            1
# 4                                2                            1

# %%
#
#
#  TREINANDO O MODELO - UTILIZANDO RANDOM XGBoost
#
#

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.over_sampling import SMOTE

# %%
# Colunas de entrada
X_cols = [
    'dados_pessoais: sexo',
    'dados_pessoais: faixa_etaria', 'dados_pessoais: posicao_quadra',
    'experiencia: tempo_padel', 'experiencia: quantidade_treinos',
    'experiencia: quantidade_jogos', 'experiencia: participa_torneios',
    'experiencia: categoria_em_torneios', 'habilidade_tecnica: saque',
    'habilidade_tecnica: voleio', 'habilidade_tecnica: smash',
    'habilidade_tecnica: movimentacao', 'composicao_jogo: defesa_ataque',
    'composicao_jog0: controle_ritmo', 'objetivo: estilo_duplas', 'composicao_jogo: saque',
    'composicao_jogo: usa_retoque', 'composicao_jogo: voleio_ataque',
    'composicao_jogo: voleio_defesa_contensao',
    'composicao_jogo: bandeja_retomada_rede', 'composicao_jogo: smash',
    'composicao_jogo: troca_bola_fundo_forehand',
    'composicao_jogo: troca_bola_fundo_backhand',
    'composicao_jogo: devolucao_saque',
    'composicao_jogo: saida_parede_defesa',
    'composicao_jogo: saida_parede_ataque', 'composicao_jogo: movimentacao',
    'composicao_jogo: posicionamento'
]

# Colunas de saída
y_cols = ['autoavaliacao: categoria']

# Separar X e y
X = df[X_cols]
y = df[y_cols]['autoavaliacao: categoria']

# %%
# Transformar y em Series
y_series = y.squeeze()  # se y era DataFrame 1 coluna, vira Series

# Identificar a classe com apenas 1 amostra
classe_unica = y_series.value_counts()[y_series.value_counts() == 1].index[0]

# Duplicar a linha correspondente
X = pd.concat([X, X[y_series == classe_unica]], ignore_index=True)
y = pd.concat([y_series, y_series[y_series == classe_unica]], ignore_index=True)

# %%
# 2️⃣ Mapear y para começar em 0
y_mapped = y - 1  # se os valores originais vão de 1 a 8, agora vão de 0 a 7

# 3️⃣ Separar treino e teste
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y_mapped, test_size=0.2, random_state=42, stratify=y_mapped
)

# 4️⃣ Treinar XGBoost
from xgboost import XGBClassifier

model = XGBClassifier(
    objective='multi:softmax',
    num_class=len(y_mapped.unique()),
    random_state=42,
    eval_metric='mlogloss'
)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None, num_class=8, ...)

# %%
y_pred = model.predict(X_test)

# %%
print("Acurácia:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Matriz de Confusão:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Acurácia: 0.5277777777777778
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         2
#            1       0.00      0.00      0.00         3
#            2       1.00      0.50      0.67         6
#            3       0.67      0.57      0.62         7
#            4       0.62      0.50      0.56        10
#            5       0.40      0.67      0.50         6
#            6       0.50      0.50      0.50         2
#
#     accuracy                           0.53        36
#    macro avg       0.50      0.53      0.48        36
# weighted avg       0.58      0.53      0.52        36
#
# Matriz de Confusão:
# [[2 0 0 0 0 0 0]
#  [3 0 0 0 0 0 0]
#  [1 0 3 2 0 0 0]
#  [0 1 0 4 2 0 0]
#  [0 0 0 0 5 5 0]
#  [0 0 0 0 1 4 1]
#  [0 0 0 0 0 1 1]]
